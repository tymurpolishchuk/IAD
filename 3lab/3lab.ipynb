# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Life_Exp_Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.tail(3)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# ...

# %%
dc = df.dropna()
dc.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  1649.000000       1649.000000      1649.000000    1649.000000
# mean   2007.840509         69.302304       168.215282      32.553062
# std       4.087711          8.796834       125.310417     120.847190
# min    2000.000000         44.000000         1.000000       0.000000
# 25%    2005.000000         64.400000        77.000000       1.000000
# 50%    2008.000000         71.700000       148.000000       3.000000
# 75%    2011.000000         75.000000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
df.sample(10)
# Out:
#                                Country  Year      Status  Life expectancy   \
# 1740                        Montenegro  2007  Developing              74.2
# 2220             Sao Tome and Principe  2012  Developing              66.9
# 239                            Belarus  2000  Developing              68.0
# 338                           Botswana  2013  Developing              64.2
# 1206                         Indonesia  2011  Developing              68.3
# 1735                        Montenegro  2012  Developing              75.6
# 700                            Czechia  2004   Developed              75.8
# 2194  Saint Vincent and the Grenadines  2005  Developing              71.4
# 2496                         Swaziland  2008  Developing              51.4
# 380                  Brunei Darussalam  2003  Developing              76.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1740            125.0              0     4.98              678.518894
# ...

# %%
df.nlargest(10, ['Life expectancy ', 'Year'])
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 241       Belgium  2014   Developed              89.0             76.0
# 915       Finland  2014  Developing              89.0             78.0
# 995       Germany  2014   Developed              89.0             69.0
# 2056     Portugal  2014   Developed              89.0             78.0
# 1850  New Zealand  2010   Developed              89.0             71.0
# 1916       Norway  2009   Developed              89.0             67.0
# 937        France  2008  Developing              89.0             88.0
# 938        France  2007  Developing              89.0             89.0
# 2433        Spain  2007   Developed              89.0             72.0
# 2513       Sweden  2007   Developed              89.0             63.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 241               0    12.60             7163.348923         98.0        70
# ...

# %%
#df = df.drop(columns=['Period'])
df.nsmallest(10, ['Life expectancy ', 'Year'])
# Out:
#            Country  Year      Status  Life expectancy   Adult Mortality  \
# 1127         Haiti  2010  Developing              36.3            682.0
# 2312  Sierra Leone  2000  Developing              39.0            533.0
# 2311  Sierra Leone  2001  Developing              41.0            519.0
# 2309  Sierra Leone  2003  Developing              41.5             57.0
# 2308  Sierra Leone  2004  Developing              42.3            496.0
# 1585        Malawi  2000  Developing              43.1            588.0
# 2307  Sierra Leone  2005  Developing              43.3             48.0
# 1584        Malawi  2001  Developing              43.5            599.0
# 2921        Zambia  2000  Developing              43.8            614.0
# 1583        Malawi  2002  Developing              44.0             67.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1127             23     5.76               36.292918          NaN         0
# ...

# %%
df[df["Country"] == "Ukraine"]
# Out:
#       Country  Year      Status  Life expectancy   Adult Mortality  \
# 2730  Ukraine  2015  Developing              71.3            195.0
# 2731  Ukraine  2014  Developing              78.0             23.0
# 2732  Ukraine  2013  Developing              71.0            198.0
# 2733  Ukraine  2012  Developing              77.0             25.0
# 2734  Ukraine  2011  Developing              75.0             24.0
# 2735  Ukraine  2010  Developing              69.8            212.0
# 2736  Ukraine  2009  Developing              69.2            231.0
# 2737  Ukraine  2008  Developing              67.7            273.0
# 2738  Ukraine  2007  Developing              67.5            277.0
# 2739  Ukraine  2006  Developing              67.7            267.0
# 2740  Ukraine  2005  Developing              67.0            278.0
# 2741  Ukraine  2004  Developing              67.4            267.0
# 2742  Ukraine  2003  Developing              67.6            256.0
# ...

# %%
df['Status'].value_counts(normalize=True)
# Out:
# Developing    0.825732
# Developed     0.174268
# Name: Status, dtype: float64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df1 = df.drop(columns=['Year', 'Income composition of resources', 'Schooling', 'percentage expenditure', 'under-five deaths '])
df2 = df1.corr()
plt.figure(figsize=(16,12))

# Create a custom diverging palette
cmap = sns.diverging_palette(250, 15, s=75, l=40, n=9, center="light", as_cmap=True)
_ = sns.heatmap(df2, center=0, annot=True, fmt='.2f', square=True, cmap=cmap)

# %%
cols = ['Hepatitis B', 'Polio', 'Diphtheria', 'BMI'] 
dfc = df[["Hepatitis B", "Polio", "Diphtheria ", " BMI "]]
dfc = dfc.cov()
plt.figure(figsize=(8,8))
plt.title('This matrix showing covariance and variance coefficients', size = 16)
sns.set(font_scale=1.5)
hm = sns.heatmap(dfc,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 12},
                 cmap='coolwarm',                 
                 yticklabels=cols,
                 xticklabels=cols)
plt.tight_layout()
plt.show()

# %%
dc1 = df.dropna(subset=['Hepatitis B'])
dc2 = df.dropna(subset=['Polio'])
dc3 = df.dropna(subset=['Diphtheria '])
dc4 = df.dropna(subset=[' thinness  1-19 years'])
sns.set(style="darkgrid")
sns.histplot(data=dc1, x="Hepatitis B", color="skyblue", label="Hepatitis B", kde=True)
sns.histplot(data=dc2, x="Polio", color="red", label="Polio", kde=True)
sns.histplot(data=dc3, x="Diphtheria ", color="gold", label="Diphtheria", kde=True)
plt.legend() 
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7)) 
sns.histplot(data=dc1, x="Hepatitis B", kde=True, color="skyblue", bins = 25, ax=axs[0, 0])
sns.histplot(data=dc2, x="Polio", kde=True, color="olive", bins = 25, ax=axs[0, 1])
sns.histplot(data=dc3, x="Diphtheria ", kde=True, color="gold", bins = 25, ax=axs[1, 0])
sns.histplot(data=dc4, x=" thinness  1-19 years", kde=True, color="teal", bins = 25, ax=axs[1, 1])
plt.show()

# %%
dc5 = df.dropna(subset=['GDP'])
sns.scatterplot(data = dc5, x = "infant deaths", y = "GDP")
sns.rugplot(data = dc5, x = "infant deaths", y = "GDP")
# Out:
# <AxesSubplot:xlabel='infant deaths', ylabel='GDP'>

# %%
df3 = df.dropna(subset=['Population'])
#df3 = df3[df3['Population'] > 1000000]
df3 = df3[df3["Country"].str.contains("Albania|Australia|Armenia|Austria") == False].head(70)
sns.set_style("whitegrid")  
sns.boxplot(x = df3['Country'], y = df3['Population'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Population'>

# %%
df4 = df[["Status", "Life expectancy "]]
df4.groupby(['Status']).mean()
# Out:
#             Life expectancy
# Status
# Developed          79.197852
# Developing         67.111465

# %%
df5 = df[["Adult Mortality", "Alcohol", " BMI ",  "Polio", "Diphtheria ", " HIV/AIDS", "GDP", "Schooling", "Life expectancy "]]
df5 = df5.corr()
df5
# Out:
#                   Adult Mortality   Alcohol      BMI      Polio  Diphtheria   \
# Adult Mortality          1.000000 -0.195848 -0.387017 -0.274823    -0.275131
# Alcohol                 -0.195848  1.000000  0.330408  0.221734     0.222020
#  BMI                    -0.387017  0.330408  1.000000  0.284569     0.283147
# Polio                   -0.274823  0.221734  0.284569  1.000000     0.673553
# Diphtheria              -0.275131  0.222020  0.283147  0.673553     1.000000
#  HIV/AIDS                0.523821 -0.048845 -0.243717 -0.159560    -0.164860
# GDP                     -0.296049  0.354712  0.301557  0.211976     0.200666
# Schooling               -0.454612  0.547378  0.546961  0.417866     0.425332
# Life expectancy         -0.696359  0.404877  0.567694  0.465556     0.479495
#
#                    HIV/AIDS       GDP  Schooling  Life expectancy
# Adult Mortality    0.523821 -0.296049  -0.454612         -0.696359
# ...

# %%
plt.figure(figsize=(16,12))
#cmap = sns.color_palette("Greens", as_cmap=True)
cmap = sns.color_palette("YlOrBr", as_cmap=True)
h3 = sns.heatmap(df5, center=0, annot=True, fmt='.2f', square=True, cmap=cmap)

# %%
dc6= df.dropna(subset=['Life expectancy ', 'Schooling'])
sns.scatterplot(data=dc6, x="Life expectancy ", y="Schooling", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Schooling'>

# %%
dc7= df.dropna(subset=['Life expectancy ', 'GDP'])
sns.scatterplot(data=dc7, x="Life expectancy ", y="GDP", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='GDP'>

# %%
plt.rcParams['figure.figsize'] = [8, 8]
data = df[df["Year"] == 2015]
data= data.dropna(subset=['Life expectancy ', 'GDP', 'Population'])
sns.scatterplot(data=data, x="GDP", y="Life expectancy ", hue="Status", size="Population", style="Status", legend=False, sizes=(20, 2000))
plt.show()

# %%
sns.scatterplot(data=df, x="Life expectancy ", y="Adult Mortality", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Adult Mortality'>

# %%
sns.scatterplot(data=df, x="Life expectancy ", y=" HIV/AIDS", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel=' HIV/AIDS'>

# %%
dc8= df.dropna(subset=['Life expectancy ', 'Income composition of resources'])
sns.scatterplot(data=dc8, x="Life expectancy ", y="Income composition of resources", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Income composition of resources'>

# %%
df7 = df
bins = [0, 65, np.inf]
category = ['less 65', 'more 65']
#df7 = df7.drop(columns=['Period'])
df7['Period'] = pd.cut(df7['Life expectancy '], bins, labels=category)
df7= df7.dropna(subset=['Life expectancy ', 'Total expenditure'])
sns.scatterplot(data=df7, x="Life expectancy ", y="Total expenditure", hue="Period", style="Period")
#витрати на охорону здоров'я збільшувати не потрібно
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Total expenditure'>

# %%
df8 = df[["Adult Mortality", "infant deaths", "under-five deaths ", "Life expectancy "]]
df8 = df8.corr()
df8
# Out:
#                     Adult Mortality  infant deaths  under-five deaths   \
# Adult Mortality            1.000000       0.078756            0.094146
# infant deaths              0.078756       1.000000            0.996629
# under-five deaths          0.094146       0.996629            1.000000
# Life expectancy           -0.696359      -0.196557           -0.222529
#
#                     Life expectancy
# Adult Mortality            -0.696359
# infant deaths              -0.196557
# under-five deaths          -0.222529
# Life expectancy             1.000000

# %%
sns.scatterplot(data=df7, x="Life expectancy ", y="infant deaths")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='infant deaths'>

# %%
df9 = df[["Alcohol", " BMI ", "Life expectancy "]]
df9 = df9.corr()
df9
# Out:
#                    Alcohol      BMI   Life expectancy
# Alcohol           1.000000  0.330408          0.404877
#  BMI              0.330408  1.000000          0.567694
# Life expectancy   0.404877  0.567694          1.000000

# %%
sns.jointplot(data=df, x="Life expectancy ", y=" BMI ", kind="hex")

# %%
sns.scatterplot(data=dc7, x="Life expectancy ", y="Schooling", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Schooling'>

# %%
df10 = df[["Life expectancy ", "Schooling", "Alcohol"]]
df10 = df10.corr()
df10
# Out:
#                   Life expectancy   Schooling   Alcohol
# Life expectancy           1.000000   0.751975  0.404877
# Schooling                 0.751975   1.000000  0.547378
# Alcohol                   0.404877   0.547378  1.000000

# %%
dc9 = df.dropna(subset=['Life expectancy ', 'Alcohol'])
sns.scatterplot(data=dc9, x="Life expectancy ", y="Alcohol", hue="Status", style="Status")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Alcohol'>
